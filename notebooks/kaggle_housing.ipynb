# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
DATAPATH='../data/'
train=pd.read_csv(DATAPATH+"train.csv")
test=pd.read_csv(DATAPATH+"test.csv")

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
def print_nans(x:pd.DataFrame) -> type(None):

    for i in train.columns:
        print(f"{i} Has ",train[i].isnull().sum(),f" np.NaN's ({round((1-(train.shape[0]-train[i].isnull().sum())/train.shape[0])*100,2)}%)",sep='')
    return None
# Out:
# Id Has 0 np.NaN's (0.0%)
# MSSubClass Has 0 np.NaN's (0.0%)
# MSZoning Has 0 np.NaN's (0.0%)
# LotFrontage Has 259 np.NaN's (17.74%)
# LotArea Has 0 np.NaN's (0.0%)
# Street Has 0 np.NaN's (0.0%)
# Alley Has 1369 np.NaN's (93.77%)
# LotShape Has 0 np.NaN's (0.0%)
# LandContour Has 0 np.NaN's (0.0%)
# Utilities Has 0 np.NaN's (0.0%)
# LotConfig Has 0 np.NaN's (0.0%)
# LandSlope Has 0 np.NaN's (0.0%)
# Neighborhood Has 0 np.NaN's (0.0%)
# Condition1 Has 0 np.NaN's (0.0%)
# Condition2 Has 0 np.NaN's (0.0%)
# BldgType Has 0 np.NaN's (0.0%)
# HouseStyle Has 0 np.NaN's (0.0%)
# OverallQual Has 0 np.NaN's (0.0%)
# OverallCond Has 0 np.NaN's (0.0%)
# YearBuilt Has 0 np.NaN's (0.0%)
# YearRemodAdd Has 0 np.NaN's (0.0%)
# RoofStyle Has 0 np.NaN's (0.0%)
# RoofMatl Has 0 np.NaN's (0.0%)
# Exterior1st Has 0 np.NaN's (0.0%)
# Exterior2nd Has 0 np.NaN's (0.0%)
# MasVnrType Has 8 np.NaN's (0.55%)
# MasVnrArea Has 8 np.NaN's (0.55%)
# ExterQual Has 0 np.NaN's (0.0%)
# ...

# %%
from category_encoders import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import mean_squared_error
from math import sqrt

def RMSE(y_true,y_pred):
    sqrt(mean_squared_error(y_true=y_true,y_pred=y_pred))

# %%
def print_nulls(df):
    total=0
    for col in df.columns:
        print(f"in {col} column there are {df[col].isnull().sum()} missing values")
        total+=df[col].isnull().sum()
    print(f"total amount of missing values in this df is {total}\nor about {round((total/(df.shape[0]*df.shape[1])),4)}% of all values")
print_nulls(train)
